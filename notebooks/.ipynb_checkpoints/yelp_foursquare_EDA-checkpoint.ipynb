# %%
# imports
import requests
import pandas as pd
import json
import os

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
api_key = os.environ["FOURSQUARE_API_KEY"]

url = "https://api.foursquare.com/v3/places/search"

headers = {
    "Accept": "application/json",
    "Authorization": api_key
}

FourSquareDB = pd.DataFrame(columns = ['Station Name', 'Venue Name', 'Distance', 'Primary Category']) #Setting up the empty DataFrame for the FourSquare data to be stored.

for row in output.index: #The ouput DataFrame is retrieved directly from the city_bikes notebook. Each row is iterated on to retrieve information.
    StationName = str(
        output['Station Name'][row]
    )
    Lat = str(
        output['Latitude'][row]
    )
    Long = str(
        output['Longitude'][row]
    )
    LatLong = Lat + ',' + Long #Latitude and Longitude are formatted to adhere to what FourSquare needs.
    
    params = { #The parameters for the GET request are set with the coordinates pulled from the row.
        "query": "restaurant",
        "ll": LatLong,
        "radius": 500, #A small radius of 500m was chosen. Vienna is a fairly concentrated city with a lot of biking. 1000m leads to an excessive amount of overlap.
        "sort":"DISTANCE" #A few businesses above 500m still show up. One is almost 10km away from the station, but it won't be difficult to remove.
    }
    
    response = requests.request(
        "GET", url, params=params, headers=headers
    )
    
    tempJson = json.loads(
        response.text
    )
    tempdb = pd.json_normalize(#The output from the GET request is stored in a temporary DataFrame.
        tempJson['results']
    )
    
    for venue in tempdb.index: #The temporary DataFrame is iterated over, collecting the name and distance of the venues.
        VenueName = tempdb['name'][venue]
        Distance = tempdb['distance'][venue]
        PrimaryCategory = tempdb['categories'][venue][0]['name']
        new_row = pd.Series({
             'Station Name': StationName, #Including the Station Name here should make it much easier to join the data later.
             'Venue Name': VenueName, 
             'Distance': Distance,
             'Primary Category': PrimaryCategory
        } #I chose variables that were only available in both FourSquare and Yelp. This does leave out some later possibility for analysis, but the effectiveness of that analysis would be questionable in my opinion.   
        )        
        FourSquareDB = pd.concat(
            [FourSquareDB, new_row.to_frame().T], #The DataFrame is filled with the data collected from FourSquare.
            ignore_index = True
        )
    
    

FourSquareDB.to_csv('four_square_venues.csv', index=False) #The DataFrame is then stored in a csv for later use.
FourSquareDB

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
#Chose to retrieve the Venue Name, Distance, and Category from the Station.

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
FourSquareDB = pd.read_csv('four_square_venues.csv')
FourSquareDB.sort_values('Distance', ascending = False)
# Out:
#             Station Name                             Venue Name  Distance  \
# 1257           Liesing S                                DerMann      9676
# 870      Auf der Schmelz                               Das Cafe      3342
# 118     Alfred-Böhm-Park                  China-Restaurant Jade       905
# 117     Alfred-Böhm-Park                            Cafe City X       548
# 869      Auf der Schmelz                 China-Restaurant Sunny       507
# ...                  ...                                    ...       ...
# 770          Albertgasse                              Delibluem         6
# 60    Media Quarter Marx  Restaurant Peter & Paul Deli & Bistro         5
# 1458       Schönbornpark                             Via Toledo         4
# 424          Rochusmarkt                 Rojda Grill Restaurant         2
# 30           Volksgarten                       Asia-Noodle Bude         2
#
#                      Primary Category
# 1257                           Bakery
# 870                              Café
# 118                  Asian Restaurant
# 117                              Café
# 869                Chinese Restaurant
# ...                               ...
# 770   Vegan and Vegetarian Restaurant
# 60                Dining and Drinking
# 1458                         Pizzeria
# 424                Turkish Restaurant
# 30                        Snack Place
#
# [1648 rows x 4 columns]

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
API_KEY = os.environ["YELP_FUSION_API_KEY"]

headers = {
    "accept": "application/json",
    "authorization": 'bearer %s' % API_KEY #This entire code is pretty much the same as the one I made for FourSquare with a couple of differences. Yelp needs this weird bearer thing which I don't understand the logic behind but whatever. 
          }

YelpFusionDB = pd.DataFrame(columns = ['Station Name', 'Venue Name', 'Distance', 'Ratings', 'Review Count', 'Primary Category']) 

for row in output.index:
    StationName = str(
        output['Station Name'][row]
    )
    Lat = str(
        output['Latitude'][row]
    )
    Long = str(
        output['Longitude'][row]
    )
    params = {
        "query": "restaurant",
        "latitude": Lat, #Latitude and Longitude are taken separately here, as that is what Yelp requires.
        "longitude": Long,
        "radius": 500, #For some reason this parameter doesn't appear to work perfectly. I got some businesses up to a range of ~700m on Yelp. Not sure what's up with that, so I'll filter it later.
        "sort":"DISTANCE"
    }
    
    response = requests.request(
        "GET", url, params=params, headers=headers
    )
    
    tempJson = json.loads(
        response.text
    )
    tempdb = pd.json_normalize(
        tempJson['businesses']
    )
    
    for venue in tempdb.index:
        VenueName = tempdb['name'][venue]
        Distance = tempdb['distance'][venue]
        Rating = tempdb['rating'][venue]
        ReviewCount = tempdb['review_count'][venue]
        PrimaryCategory = tempdb['categories'][venue][0]['title']
        new_row = pd.Series({
            'Station Name': StationName, 
            'Venue Name': VenueName, 
            'Distance': Distance,
            'Ratings': Rating,
            'Review Count': ReviewCount,
            'Primary Category': PrimaryCategory
        } #In addition to the columns taken from FourSquare, Ratings and Review Count were also collected.
        )        
        YelpFusionDB = pd.concat(
            [YelpFusionDB, new_row.to_frame().T], 
            ignore_index = True
        )
    

    
YelpFusionDB.to_csv('yelp_fusion_venues.csv', index=False) #DataFrame is saved to a csv so I don't have to run this code again.
YelpFusionDB

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
YelpFusionDB = pd.read_csv('yelp_fusion_venues.csv')
YelpFusionDB
# Out:
#            Station Name          Venue Name    Distance  Ratings  \
# 0     Julius-Raab-Platz                Yori  105.331498      4.0
# 1     Julius-Raab-Platz      Motto am Fluss  322.817212      4.0
# 2     Julius-Raab-Platz  Da Capo Ristorante  610.526069      4.5
# 3     Julius-Raab-Platz           Holy Moly   72.439778      4.0
# 4     Julius-Raab-Platz                Ef16  425.542327      4.5
# ...                 ...                 ...         ...      ...
# 3016    Am Langen Felde     Jun Thai Imbiss  417.595893      5.0
# 3017    Am Langen Felde    Pizzeria Riviera  337.240970      3.0
# 3018    Am Langen Felde        Curry Leaves  367.861821      3.0
# 3019    Am Langen Felde    Kebap/Wok Kagran  330.725738      4.0
# 3020    Am Langen Felde                Ying  692.554976      3.0
#
#       Review Count Primary Category
# 0               53           Korean
# 1              144         Austrian
# 2              108            Pizza
# 3               25      Restaurants
# 4               50        Wine Bars
# ...            ...              ...
# 3016             1             Thai
# 3017             1            Pizza
# 3018             1           Indian
# 3019             1      Food Stands
# 3020             2          Chinese
#
# [3021 rows x 6 columns]

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# I prefer FourSquare for the sake of actual data analysis. Yelp provides a larger variety of information, but much of it appears to be unreliable. For example, using the rating of a business that has just a couple of reviews seems unwise. Many businesses have no reviews whatsoever, and are missing some other datapoints that would be nice to use in analysis. More popular areas and businesses should be ok when it comes to using reviews and ratings. FourSquare on the other hand offers data that is a little bit more limited in scope, but it all appears to be a bit more reliable.
#
# Yelp provided more data, but the data that FourSquare provided felt more complete.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
#I selected the top 10 restaurants from some nearby coordinates.

params = {
    "query": "restaurant",
    "latitude": 48,
    "longitude": 16.4,
    "radius": 5000,
    "sort":"DISTANCE"
}

response = requests.request("GET", url, params=params, headers=headers)
print(response.text)

tempJson = json.loads(response.text)

tempdb = pd.json_normalize(tempJson['businesses'])

testdb.to_csv('raw_yelp.csv', index = False)

YelpFusionDB2 = pd.read_csv('raw_yelp.csv')

YelpFusionDB2.sort_values('rating', ascending = False).head(10)
# Out:
#                         id                                             alias  \
# 0   Q84VMYA7rsEc_gihnPotww                               klein-und-fein-velm
# 1   VCJrcyUmnD8jxXgtzhoMNg                   pichlers-restaurant-münchendorf
# 3   7Xf2ZerUURYIEXZM94IeyQ  pizzeria-u-kebap-house-ebreichsdorf-ebreichsdorf
# 4   0If5YKAjIOy6F3m_tDpi2w                        zur-mina-tant-ebreichsdorf
# 8   EDaXxxafSR9LcCR_SpF3jA                               sgwölb-ebreichsdorf
# 9   B1viEoAzNVOA2ZjOVU2joA                         brunners-bräu-münchendorf
# 2   htKZC0IGhS1N26PrYwbGUQ               heuriger-dreimäderlhaus-münchendorf
# 6   -iXlZK2qS5RZepd4pHBulQ                    eiscafé-garibaldi-ebreichsdorf
# 7   _JbN9FY5R2DUXsESowgXtQ                    pizzeria-d-angelo-ebreichsdorf
# 10  5VSfr5YVxIG6FGnDy1NKsg                        weißer-schwan-ebreichsdorf
#
#                                     name  \
# 0                           Klein & Fein
# 1                    Pichlers Restaurant
# 3   Pizzeria u. Kebap House Ebreichsdorf
# 4                          Zur Mina Tant
# 8                                S'Gwölb
# 9                         Brunner's Bräu
# 2                Heuriger Dreimäderlhaus
# 6                      Eiscafé Garibaldi
# 7                      Pizzeria D'Angelo
# 10                         Weißer Schwan
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/DoontB...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/F1-z4w...      False
# 3                                                 NaN      False
# 4                                                 NaN      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/51CJ7u...      False
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/Ko8sMn...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/qWHfEw...      False
# 6                                                 NaN      False
# 7                                                 NaN      False
# 10                                                NaN      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/klein-und-fein-velm?a...             1
# 1   https://www.yelp.com/biz/pichlers-restaurant-m...             3
# 3   https://www.yelp.com/biz/pizzeria-u-kebap-hous...             1
# 4   https://www.yelp.com/biz/zur-mina-tant-ebreich...             4
# 8   https://www.yelp.com/biz/sgw%C3%B6lb-ebreichsd...             4
# 9   https://www.yelp.com/biz/brunners-br%C3%A4u-m%...             1
# 2   https://www.yelp.com/biz/heuriger-dreim%C3%A4d...             3
# 6   https://www.yelp.com/biz/eiscaf%C3%A9-garibald...             2
# 7   https://www.yelp.com/biz/pizzeria-d-angelo-ebr...             3
# 10  https://www.yelp.com/biz/wei%C3%9Fer-schwan-eb...             1
#
#                                            categories  rating  \
# 0        [{'alias': 'austrian', 'title': 'Austrian'}]     5.0
# 1   [{'alias': 'austrian', 'title': 'Austrian'}, {...     5.0
# 3   [{'alias': 'kebab', 'title': 'Kebab'}, {'alias...     5.0
# 4   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     4.0
# 8        [{'alias': 'austrian', 'title': 'Austrian'}]     4.0
# 9   [{'alias': 'food', 'title': 'Food'}, {'alias':...     4.0
# 2   [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     3.5
# 6   [{'alias': 'icecream', 'title': 'Ice Cream & F...     3.0
# 7   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 10  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.0
#
#                                           coordinates transactions price  \
# 0   {'latitude': 48.0405890142984, 'longitude': 16...           []   €€€
# 1       {'latitude': 48.02658, 'longitude': 16.37871}           []   NaN
# 3       {'latitude': 47.96345, 'longitude': 16.40307}           []     €
# 4       {'latitude': 47.97931, 'longitude': 16.44341}           []   NaN
# 8   {'latitude': 47.9722624, 'longitude': 16.3969205}           []   NaN
# 9   {'latitude': 48.0299886, 'longitude': 16.3797198}           []   NaN
# 2   {'latitude': 48.0290245, 'longitude': 16.3792488}           []   €€€
# 6         {'latitude': 47.9633, 'longitude': 16.4023}           []    €€
# 7   {'latitude': 47.9664738, 'longitude': 16.4023223}           []   NaN
# 10        {'latitude': 47.9635, 'longitude': 16.4018}           []   NaN
#
#                                              location            phone  \
# 0   {'address1': 'Velmerstr. 69', 'address2': '', ...  +43302234x78991
# 1   {'address1': 'Hauptstr. 8', 'address2': None, ...    +436769448564
# 3   {'address1': 'Bahnstraße 5', 'address2': None,...     +43225474054
# 4   {'address1': 'Untere Ortsstr. 2', 'address2': ...     +43225473478
# 8   {'address1': 'Rathausplatz 2', 'address2': '',...   +4369912165103
# 9   {'address1': 'Hauptstr. 46', 'address2': None,...   +4369911602622
# 2   {'address1': 'Hauptstr. 34', 'address2': None,...      +4322592248
# 6   {'address1': 'Hauptplatz 2', 'address2': None,...    +436767226795
# 7   {'address1': 'Wiener Str. 28', 'address2': Non...     +43225476069
# 10  {'address1': 'Wiener Neustädter Str. 3', 'addr...     +43225473805
#
#             display_phone     distance
# 0   +43 302234 ext. 78991  5623.924083
# 1         +43 676 9448564  3355.392379
# 3          +43 2254 74054  4067.071031
# 4          +43 2254 73478  3965.993457
# 8        +43 699 12165103  3092.780579
# 9        +43 699 11602622  3659.908584
# 2           +43 2259 2248  3577.490647
# 6         +43 676 7226795  4084.438367
# 7          +43 2254 76069  3731.943984
# 10         +43 2254 73805  4060.820957
